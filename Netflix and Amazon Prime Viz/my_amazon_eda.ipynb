# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('amazon_prime_titles.csv')

# %%
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
df.tail()
# Out:
#      show_id     type                    title         director  \
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# 9663                           Leo Gorcey, Bobby Jordan     NaN        NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...     NaN        NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...     NaN        NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...     NaN        NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...     NaN        NaN
#
#       release_year rating   duration                listed_in  \
# 9663          1940     7+     60 min                   Comedy
# ...

# %%
df.drop(['show_id','description'], axis=1, inplace=True)

# %%
df
# Out:
#          type                    title         director  \
# 0       Movie      The Grand Seduction     Don McKellar
# 1       Movie     Take Care Good Night     Girish Joshi
# 2       Movie     Secrets of Deception      Josh Webber
# 3       Movie       Pink: Staying True   Sonia Anderson
# 4       Movie            Monster Maker     Giles Foster
# ...       ...                      ...              ...
# 9663    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show            Planet Patrol              NaN
# 9665    Movie                  Outpost     Steve Barker
# 9666  TV Show  Maradona: Blessed Dream              NaN
# 9667    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# ...

# %%
df.shape
# Out:
# (9668, 10)

# %%
df.isna().any()
# Out:
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration        False
# listed_in       False
# dtype: bool

# %%
(df.isna().sum() * 100) / df.shape[0]
# Out:
# type             0.000000
# title            0.000000
# director        21.534961
# cast            12.753413
# country         93.049235
# date_added      98.396773
# release_year     0.000000
# rating           3.485726
# duration         0.000000
# listed_in        0.000000
# dtype: float64

# %% [markdown]
# 93 % of the entries in country column, 98% in date added, 21.53% in director and 12.75% in cast column are empty

# %%
df.drop_duplicates(inplace = True)

# %%
df.drop(['country','date_added'], axis=1, inplace=True)

# %%
df
# Out:
#          type                    title         director  \
# 0       Movie      The Grand Seduction     Don McKellar
# 1       Movie     Take Care Good Night     Girish Joshi
# 2       Movie     Secrets of Deception      Josh Webber
# 3       Movie       Pink: Staying True   Sonia Anderson
# 4       Movie            Monster Maker     Giles Foster
# ...       ...                      ...              ...
# 9663    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show            Planet Patrol              NaN
# 9665    Movie                  Outpost     Steve Barker
# 9666  TV Show  Maradona: Blessed Dream              NaN
# 9667    Movie              Harry Brown    Daniel Barber
#
#                                                    cast  release_year rating  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# ...

# %%
df['type'].value_counts()
# Out:
# Movie      7814
# TV Show    1854
# Name: type, dtype: int64

# %%
sns.countplot(x='type', data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df['director'].value_counts()
# Out:
# Mark Knight                                                  113
# Cannis Holder                                                 61
# Moonbug Entertainment                                         37
# Jay Chapman                                                   34
# Arthur van Merwijk                                            30
#                                                             ...
# Robert F. Hill & Sam Katzman, Robert F. Hill, Sam Katzman      1
# Pratima Joshi                                                  1
# Nick Frangione                                                 1
# Walter V Marshall                                              1
# C. V. Sasikumar                                                1
# Name: director, Length: 5774, dtype: int64

# %%
print(df.rating.unique())
# Out:
# [nan '13+' 'ALL' '18+' 'R' 'TV-Y' 'TV-Y7' 'NR' '16+' 'TV-PG' '7+' 'TV-14'
#  'TV-NR' 'TV-G' 'PG-13' 'TV-MA' 'G' 'PG' 'NC-17' 'UNRATED' '16' 'AGES_16_'
#  'AGES_18_' 'ALL_AGES' 'NOT_RATE']

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

fig_dimensions = (30,25)
fig, ax = plt.subplots(figsize=fig_dimensions)

ratings_plot = sns.countplot(x=df['rating'], data=df)

ratings_plot.set_xlabel('Rating Type')
ratings_plot.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.head(5)
# Out:
#     type                 title        director  \
# 0  Movie   The Grand Seduction    Don McKellar
# 1  Movie  Take Care Good Night    Girish Joshi
# 2  Movie  Secrets of Deception     Josh Webber
# 3  Movie    Pink: Staying True  Sonia Anderson
# 4  Movie         Monster Maker    Giles Foster
#
#                                                 cast  release_year rating  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017    NaN
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014    NaN
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989    NaN
#
#   duration                listed_in
# 0  113 min            Comedy, Drama
# 1  110 min     Drama, International
# 2   74 min  Action, Drama, Suspense
# 3   69 min              Documentary
# 4   45 min           Drama, Fantasy

# %%
sns.displot(x='release_year',data=df)

# %%
df.groupby('release_year').size().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
df["rating"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_movies = df[df['type']=='Movie']

# %%
df_shows = df[df['type']=='TV Show']

# %%
df_movies
# Out:
#        type                 title                             director  \
# 0     Movie   The Grand Seduction                         Don McKellar
# 1     Movie  Take Care Good Night                         Girish Joshi
# 2     Movie  Secrets of Deception                          Josh Webber
# 3     Movie    Pink: Staying True                       Sonia Anderson
# 4     Movie         Monster Maker                         Giles Foster
# ...     ...                   ...                                  ...
# 9660  Movie    The Man in the Hat  John-Paul Davidson, Stephen Warbeck
# 9662  Movie                 River                           Emily Skye
# 9663  Movie   Pride Of The Bowery                      Joseph H. Lewis
# 9665  Movie               Outpost                         Steve Barker
# 9667  Movie           Harry Brown                        Daniel Barber
#
#                                                    cast  release_year rating  \
# ...

# %%
df_movies.sort_values(['duration'], ascending = False)
# Out:
#        type                                         title  \
# 9433  Movie                                Red Sun Rising
# 4875  Movie                 Nightingale: A Melody of Life
# 9524  Movie                                    The Trench
# 7328  Movie                       The Woman In The Window
# 199   Movie                               Valley Uprising
# ...     ...                                           ...
# 1590  Movie                     Movie_Project_UN_Test_UHD
# 1381  Movie        Paradise Canyon - Digitally Remastered
# 8575  Movie                ProjectUNUnApprovedMovieTarget
# 5191  Movie                      Asintombstonetest-target
# 788   Movie  Testing title - Parichey is using this title
#
#                        director  \
# 9433             Francis Megahy
# 4875        Gowtham Namasivayam
# 9524               William Boyd
# 7328                 Fritz Lang
# 199   Pete Mortimer, Nick Rosen
# ...                         ...
# 1590              Test Director
# ...

# %%
df_shows
# Out:
#          type                          title director  \
# 17    TV Show                     Zoo Babies      NaN
# 18    TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 20    TV Show                     Zoboomafoo      NaN
# 21    TV Show      Zo Zo Zombie: Mini-Series      NaN
# 23    TV Show                   ZeroZeroZero      NaN
# ...       ...                            ...      ...
# 9651  TV Show                     Glass Room      NaN
# 9655  TV Show          DaFUNdamentals Series      NaN
# 9661  TV Show                     Terrahawks      NaN
# 9664  TV Show                  Planet Patrol      NaN
# 9666  TV Show        Maradona: Blessed Dream      NaN
#
#                                                    cast  release_year rating  \
# 17                           Narrator - Gillian Barlett          2008    ALL
# 18                                      Zoë Coombs Marr          2020    18+
# 20                                                  NaN          2001   TV-Y
# ...

# %%
df_shows.sort_values(['duration'], ascending = False)
# Out:
#          type                                           title director  \
# 800   TV Show                                       Teen Wolf      NaN
# 185   TV Show                                         Vikings      NaN
# 1081  TV Show                                          Scrubs      NaN
# 3571  TV Show                                    'Allo 'Allo!      NaN
# 867   TV Show                                           Suits      NaN
# ...       ...                                             ...      ...
# 2019  TV Show                        Jimmy O. Yang: Good Deal      NaN
# 2018  TV Show  Jingle Burgers - A Parry Gripp Christmas Album      NaN
# 2016  TV Show                Joanna Lumley: Jewel in the Nile      NaN
# 2007  TV Show                                Johnny Houser VS      NaN
# 9666  TV Show                         Maradona: Blessed Dream      NaN
#
#                                                    cast  release_year rating  \
# ...

# %%
df['cast'].value_counts()
# Out:
# Maggie Binkley                                                                               56
# 1                                                                                            34
# Anne-Marie Newland                                                                           24
# Cassandra Peterson                                                                           21
# Grace Tamayo, Erin Webbs                                                                     17
#                                                                                              ..
# Farid Jamal Khan, Tiamarie Carvey, Jake Berry, Masie Dee, Satine Spark                        1
# Katie Leclerc, Jonathan Bennett, Jack McGee, Andrea Sixtos, William Belli, Shelby Wulfurt     1
# Brendan Fletcher, Shaun Sipos, Michael Paré                                                   1
# Martin Clunes, Katie Lyons, Claudie Blakley, Stephen Wight                                    1
# ...

# %%
df_actors = df['cast']

# %%
df_actors
# Out:
# 0          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
# 3       Interviews with: Pink, Adele, Beyoncé, Britney...
# 4       Harry Dean Stanton, Kieran O'Brien, George Cos...
#                               ...
# 9663                             Leo Gorcey, Bobby Jordan
# 9664    DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...
# 9665    Ray Stevenson, Julian Wadham, Richard Brake, M...
# 9666    Esteban Recagno, Ezequiel Stremiz, Luciano Vit...
# 9667    Michael Caine, Emily Mortimer, Joseph Gilgun, ...
# Name: cast, Length: 9668, dtype: object

# %%
df
# Out:
#          type                    title         director  \
# 0       Movie      The Grand Seduction     Don McKellar
# 1       Movie     Take Care Good Night     Girish Joshi
# 2       Movie     Secrets of Deception      Josh Webber
# 3       Movie       Pink: Staying True   Sonia Anderson
# 4       Movie            Monster Maker     Giles Foster
# ...       ...                      ...              ...
# 9663    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show            Planet Patrol              NaN
# 9665    Movie                  Outpost     Steve Barker
# 9666  TV Show  Maradona: Blessed Dream              NaN
# 9667    Movie              Harry Brown    Daniel Barber
#
#                                                    cast  release_year rating  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# ...

# %%
df.sort_values(['release_year'], ascending=False)
# Out:
#        type                               title               director  \
# 5438  Movie                          No Strings            Rebecca Ugo
# 5543  Movie                      Deadly Passion  Jasmine  Jamar Alston
# 6234  Movie  Go to School and Learn with Blippi            Stevin John
# 6834  Movie     Where is Chicky? - Chapter Five        William Hoareau
# 8008  Movie                        Sema Thimiru          Nandha kishor
# ...     ...                                 ...                    ...
# 1143  Movie                 Robin Hood (Silent)             Allan Dwan
# 1425  Movie                  One Exciting Night          D.W. Griffith
# 1284  Movie                           Pollyanna            Paul Powell
# 1474  Movie                 Nomads Of The North         David Hartford
# 83    Movie                    Within Our Gates         Oscar Micheaux
#
#                                                    cast  release_year rating  \
# ...

# %% [markdown]
# The latest release was in the year 2021 while the oldest movie in the dataset was released in 1920

# %%
from plotly import graph_objects as go
from plotly import express as px

# %%
df
# Out:
#          type                    title         director  \
# 0       Movie      The Grand Seduction     Don McKellar
# 1       Movie     Take Care Good Night     Girish Joshi
# 2       Movie     Secrets of Deception      Josh Webber
# 3       Movie       Pink: Staying True   Sonia Anderson
# 4       Movie            Monster Maker     Giles Foster
# ...       ...                      ...              ...
# 9663    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show            Planet Patrol              NaN
# 9665    Movie                  Outpost     Steve Barker
# 9666  TV Show  Maradona: Blessed Dream              NaN
# 9667    Movie              Harry Brown    Daniel Barber
#
#                                                    cast  release_year rating  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014    NaN
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018    13+
# ...
