# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# For our analysis, show_id, cast, description will be dropped

# %%
df.drop(['show_id','cast','description'], axis = 1, inplace=True)

# %%
df
# Out:
#          type                  title         director        country  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1     TV Show          Blood & Water              NaN   South Africa
# 2     TV Show              Ganglands  Julien Leclercq            NaN
# 3     TV Show  Jailbirds New Orleans              NaN            NaN
# 4     TV Show           Kota Factory              NaN          India
# ...       ...                    ...              ...            ...
# 8802    Movie                 Zodiac    David Fincher  United States
# 8803  TV Show            Zombie Dumb              NaN            NaN
# 8804    Movie             Zombieland  Ruben Fleischer  United States
# 8805    Movie                   Zoom     Peter Hewitt  United States
# 8806    Movie                 Zubaan      Mozez Singh          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.isna().any()
# Out:
# type            False
# title           False
# director         True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# dtype: bool

# %%
(df.isna().sum() * 100) / df.shape[0]
# Out:
# type             0.000000
# title            0.000000
# director        29.908028
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# dtype: float64

# %% [markdown]
# On further analysis we find that almost 30% of the values in "Director" column are missing and almost 10% of the entries in country column are missing

# %%
sns.countplot(x='type', data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
print(df.rating.unique())
# Out:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' '74 min' '84 min' '66 min' 'NR' nan 'TV-Y7-FV' 'UR']

# %% [markdown]
# Now here we visualize the the ratings given to different TV shows and movies on the platform

# %%
fig = plt.figure()

# %%
fig_dimensions = (15,10)
fig, ax = plt.subplots(figsize=fig_dimensions)

ratings_plot = sns.countplot(x=df['rating'], data=df)

ratings_plot.set_xlabel('Rating Type')
ratings_plot.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# More than 3000 belong to the TV-MA category

# %%
df['country'].value_counts()
# Out:
# United States                                             2818
# India                                                      972
# United Kingdom                                             419
# Japan                                                      245
# South Korea                                                199
#                                                           ...
# Denmark, United Kingdom, South Africa, Sweden, Belgium       1
# Australia, India                                             1
# Turkey, France, Germany, Poland                              1
# Australia, France                                            1
# Ghana, United States                                         1
# Name: country, Length: 748, dtype: int64

# %%
df.head(10)
# Out:
#       type                             title                       director  \
# 0    Movie              Dick Johnson Is Dead                Kirsten Johnson
# 1  TV Show                     Blood & Water                            NaN
# 2  TV Show                         Ganglands                Julien Leclercq
# 3  TV Show             Jailbirds New Orleans                            NaN
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                              country          date_added  \
# ...

# %%
df_group = df.groupby('country')

# %%
df_group.get_group('United States').sort_values(['release_year'], ascending = False)
# Out:
#          type                                          title  \
# 1352  TV Show           Tiffany Haddish Presents: They Ready
# 1057  TV Show                      Dad Stop Embarrassing Me!
# 1310  TV Show                                       The Crew
# 459   TV Show                              Never Have I Ever
# 472   TV Show                                   Ridley Jones
# ...       ...                                            ...
# 8763    Movie                WWII: Report from the Aleutians
# 8660    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739    Movie             Why We Fight: The Battle of Russia
# 8205    Movie                           The Battle of Midway
# 7790    Movie                                 Prelude to War
#
#                          director        country         date_added  \
# 1352                          NaN  United States   February 2, 2021
# 1057                          NaN  United States     April 14, 2021
# ...

# %% [markdown]
# Here we performed groupby, and now you can see all the 2818 movies / tv shows that were made in the United States.

# %%
df['director'].value_counts()
# Out:
# Rajiv Chilaka                19
# Raúl Campos, Jan Suter       18
# Suhas Kadav                  16
# Marcus Raboy                 16
# Jay Karas                    14
#                              ..
# Michael Duggan                1
# Craig Freimond                1
# Yance Ford                    1
# Henrik Martin Dahlsbakken     1
# Gabriela García Rivas         1
# Name: director, Length: 4528, dtype: int64

# %% [markdown]
# The Director with most movies in our dataset is Rajiv Chilaka.

# %%
df["director_number"] = df["director"].str.split(',').str.len()
df["director_number"].describe()
# Out:
# count    6173.000000
# mean        1.130407
# std         0.556296
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        13.000000
# Name: director_number, dtype: float64

# %% [markdown]
# There were many movies / tv with multiple directors and it seems that max 13, that is 13 titles with multiple directors

# %%
df['date_added'].value_counts()
# Out:
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
#                     ...
# March 2, 2016          1
#  April 16, 2019        1
# April 20, 2016         1
# November 7, 2014       1
# February 21, 2017      1
# Name: date_added, Length: 1767, dtype: int64

# %% [markdown]
# Most movies / TV shows were added on Jan 1st 2020

# %%
df.sort_values(['date_added'], ascending=False)
# Out:
#          type                                     title  \
# 88      Movie  Blood Brothers: Malcolm X & Muhammad Ali
# 89    TV Show                               Mighty Raju
# 90      Movie                            Paradise Hills
# 91      Movie                The Women and the Murderer
# 2034    Movie                      So Much Love to Give
# ...       ...                                       ...
# 7196  TV Show                                  Kikoriki
# 7254  TV Show                       La Familia P. Luche
# 7406  TV Show                                     Maron
# 7847  TV Show                              Red vs. Blue
# 8182  TV Show              The Adventures of Figaro Pho
#
#                                 director               country  \
# 88                         Marcus Clarke                   NaN
# 89                                   NaN                   NaN
# 90                      Alice Waddington  Spain, United States
# ...

# %%
df.sort_values(['release_year'], ascending=False)
# Out:
#          type                                          title        director  \
# 693     Movie                         Ali & Ratu Ratu Queens  Lucky Kuswandi
# 781     Movie          Black Holes | The Edge of All We Know   Peter Galison
# 762     Movie                                   Sweet & Sour   Lee Kae-byeok
# 763   TV Show                                    Sweet Tooth             NaN
# 764     Movie                   Trippin' with the Kandasamys   Jayan Moodley
# ...       ...                                            ...             ...
# 8660    Movie  Undercover: How to Operate Behind Enemy Lines       John Ford
# 8763    Movie                WWII: Report from the Aleutians     John Huston
# 8205    Movie                           The Battle of Midway       John Ford
# 7790    Movie                                 Prelude to War     Frank Capra
# 4250  TV Show              Pioneers: First Women Filmmakers*             NaN
#
# ...

# %% [markdown]
# As Seen Above, the oldest movie on the platform was made in 1925, and the latest was in 2021.

# %%
sns.displot(x='release_year',data=df)

# %%
df.groupby('release_year').size().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
df["rating"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now lets take a look at the duration part of the data set

# %%
df.head()
# Out:
#       type                  title         director        country  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1  TV Show          Blood & Water              NaN   South Africa
# 2  TV Show              Ganglands  Julien Leclercq            NaN
# 3  TV Show  Jailbirds New Orleans              NaN            NaN
# 4  TV Show           Kota Factory              NaN          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  director_number
# 0                                      Documentaries              1.0
# 1    International TV Shows, TV Dramas, TV Mysteries              NaN
# ...

# %%
df_movies = df[df['type']=='Movie']

# %%
df_movies
# Out:
#        type                             title                       director  \
# 0     Movie              Dick Johnson Is Dead                Kirsten Johnson
# 6     Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7     Movie                           Sankofa                   Haile Gerima
# 9     Movie                      The Starling                 Theodore Melfi
# 12    Movie                      Je Suis Karl            Christian Schwochow
# ...     ...                               ...                            ...
# 8801  Movie                           Zinzana                Majid Al Ansari
# 8802  Movie                            Zodiac                  David Fincher
# 8804  Movie                        Zombieland                Ruben Fleischer
# 8805  Movie                              Zoom                   Peter Hewitt
# 8806  Movie                            Zubaan                    Mozez Singh
#
# ...

# %%
df_show = df[df['type']=='TV Show']

# %%
df_show
# Out:
#          type                  title         director  \
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# 5     TV Show          Midnight Mass    Mike Flanagan
# ...       ...                    ...              ...
# 8795  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796  TV Show             Yunus Emre              NaN
# 8797  TV Show              Zak Storm              NaN
# 8800  TV Show     Zindagi Gulzar Hai              NaN
# 8803  TV Show            Zombie Dumb              NaN
#
#                                             country          date_added  \
# 1                                      South Africa  September 24, 2021
# 2                                               NaN  September 24, 2021
# 3                                               NaN  September 24, 2021
# ...

# %%
df_show.sort_values(['duration'], ascending=False)
# Out:
#          type                          title            director  \
# 1480  TV Show                     Still Game                 NaN
# 6504  TV Show       Club Friday The Series 6                 NaN
# 67    TV Show              Saved by the Bell                 NaN
# 1998  TV Show               Call the Midwife  Philippa Lowthorpe
# 8     TV Show  The Great British Baking Show     Andy Devonshire
# ...       ...                            ...                 ...
# 3848  TV Show            Cinta Teruna Kimchi                 NaN
# 3847  TV Show       Cinta Si Wedding Planner                 NaN
# 3846  TV Show                     Cinta Iris                 NaN
# 3845  TV Show                    Cinta 100KG                 NaN
# 3696  TV Show        Record of Grancrest War                 NaN
#
#              country          date_added  release_year rating   duration  \
# 1480  United Kingdom   December 30, 2020          2018  TV-14  9 Seasons
# ...
